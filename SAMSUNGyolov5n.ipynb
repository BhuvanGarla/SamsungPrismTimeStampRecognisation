# %%
# !pip install jedi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/NewAllPics4600.zip
# !unzip /content/drive/MyDrive/FinalTestimgs.zip
# !unzip /content/drive/MyDrive/yolov5-master.zip
# Out:
# Archive:  /content/drive/MyDrive/FinalTestimgs.zip
#   inflating: Testimgs/Screenshot_20230418-023043_Messages.jpg
#   inflating: Testimgs/Screenshot_20230418-023805_Viber.jpg
#   inflating: Testimgs/Screenshot_20230418-023401_KakaoTalk.jpg
#   inflating: Testimgs/Screenshot_20230418-023610_KakaoTalk.jpg
#   inflating: Testimgs/Screenshot_20230418-023301_KakaoTalk.jpg
#   inflating: Testimgs/Screenshot_20230418-022857_Messages.jpg
#   inflating: Testimgs/Screenshot_20230418-023004_Messages.jpg
#   inflating: Testimgs/Screenshot_20230418-023305_KakaoTalk.jpg
#   inflating: Testimgs/Screenshot_20230418-023240_KakaoTalk.jpg
#   inflating: Testimgs/Screenshot_20230418-023541_KakaoTalk.jpg
#   inflating: Testimgs/Screenshot_20230418-022939_Messages.jpg
#   inflating: Testimgs/Screenshot_20230418-023742_Viber.jpg
#   inflating: Testimgs/Screenshot_20230418-022717_WhatsApp.jpg
#   inflating: Testimgs/Screenshot_20230418-022511_WhatsApp.jpg
# ...

# %%
# %pip install -qr /content/yolov5-master/requirements.txt  # install dependencies
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.9 MB/s eta 0:00:00

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.0.0+cu118 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# !python /content/yolov5-master/train.py --img 1024 --batch 8 --epochs 80 --data '/content/yolov5-master/whatsapp.yaml' --cfg /content/yolov5-master/models/yolov5n.yaml --name wm
# Out:
# 2023-04-15 01:07:08.482693: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-15 01:07:09.405147: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python yolov5-master/detect.py --source /content/Testimgs --weights /content/best-int8.tflite --img 1024
# Out:
# detect: weights=['/content/best-int8.tflite'], source=/content/Testimgs, data=yolov5-master/data/coco128.yaml, imgsz=[1024, 1024], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5-master/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-3-12 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# 2023-06-26 19:18:31.033579: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python yolov5-master/detect2.py --source /content/Testimgs --weights /content/best-int8.tflite --img 1024 --data /content/yolov5-master/data/dataset.yaml
# Out:
# detect2: weights=['/content/best-int8.tflite'], source=/content/Testimgs, data=/content/yolov5-master/data/dataset.yaml, imgsz=[1024, 1024], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5-master/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 2023-3-12 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# 2023-06-26 19:26:23.003893: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !zip -r /content/finalTest4.zip /content/yolov5-master/runs/detect/exp9
# Out:
#   adding: content/yolov5-master/runs/detect/exp9/ (stored 0%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024056_Telegram.jpg (deflated 3%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024905_Messages.jpg (deflated 11%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024939_Messages.jpg (deflated 14%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024031_Telegram.jpg (deflated 5%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024224_Telegram.jpg (deflated 4%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024540_Discord.jpg (deflated 8%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-024742_Discord.jpg (deflated 7%)
#   adding: content/yolov5-master/runs/detect/exp9/Screenshot_20230418-022857_Messages.jpg (deflated 11%)
# ...

# %%
# !python /content/yolov5-master/export.py --weights /content/best.pt --include tflite --int8 --img 1024 --data /content/yolov5-master/whatsapp.yaml
# Out:
# export: data=/content/yolov5-master/whatsapp.yaml, weights=['/content/best.pt'], imgsz=[1024], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=True, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 2023-3-12 Python-3.10.12 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# YOLOv5n summary: 157 layers, 1763224 parameters, 0 gradients
#
# PyTorch: starting from /content/best.pt with output shape (1, 64512, 8) (3.8 MB)
# 2023-06-26 19:20:46.889854: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
